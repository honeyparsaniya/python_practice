# %% [markdown]
# 1.print first n row

# %%
import pandas as pd

df=pd.read_csv("train.csv")

n=int(input("how many starting row want to print="))

print("\n====Starting rows====\n")
print(df.head(n))
# Out:
# ====Starting rows====
#
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# 2.print last n row

# %%
import pandas as pd

df=pd.read_csv("train.csv")

n=int(input("how many last row want to print="))

print("\n====last rows====\n")
print(df.tail(n))
# Out:
# ====last rows====
#
#      PassengerId  Survived  Pclass                                      Name  \
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %% [markdown]
# 3.print random rows using sample

# %%
import pandas as pd 

n=int(input("enter how many row want to print="))

print(df.sample(n))
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 724          725         1       1         Chambers, Mr. Norman Campbell
# 98            99         1       2  Doling, Mrs. John T (Ada Julia Bone)
# 576          577         1       2                  Garside, Miss. Ethel
# 866          867         1       2          Duran y More, Miss. Asuncion
#
#         Sex   Age  SibSp  Parch         Ticket     Fare Cabin Embarked
# 724    male  27.0      1      0         113806  53.1000    E8        S
# 98   female  34.0      0      1         231919  23.0000   NaN        S
# 576  female  34.0      0      0         243880  13.0000   NaN        S
# 866  female  27.0      1      0  SC/PARIS 2149  13.8583   NaN        C

# %% [markdown]
# 4.print data information

# %%
import pandas as pd

print("\n====data inforamtion===\n")
df.info()
# Out:
# ====data inforamtion===
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 5.describe data set (numaric columns)

# %%
import pandas as pd

print("\n====statical description of data====\n")
print(df.describe())
# Out:
# ====statical description of data====
#
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 6.show total row and column (using df.shape)

# %%
import pandas as pd

print("\n====shape of data frame====\n")
print("\nrow and column=",df.shape)
print("\ntotal rows=",df.shape[0])
print("\ntotal column=",df.shape[1])
# Out:
# ====shape of data frame====
#
#
# row and column= (891, 12)
#
# total rows= 891
#
# total column= 12

# %% [markdown]
# 7.show data type of all column(using df.dtype)

# %%
import pandas as pd
print("\n====column data types====\n")
print(df.dtypes)
# Out:
# ====column data types====
#
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
