# %% [markdown]
# 6. Statistics of Numeric Columns

# %%
import pandas as pd

df=pd.read_csv("data.csv")

print(df.describe())
# Out:
#             Index
# count  100.000000
# mean    50.500000
# std     29.011492
# min      1.000000
# 25%     25.750000
# 50%     50.500000
# 75%     75.250000
# max    100.000000
